# %% [markdown]
# <a href="https://colab.research.google.com/github/nvc40-coder/BTE-320-NVC/blob/main/inclassassignmentt.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
sales = float(input("Enter Sales ($): "))
rate = float(input("Enter Tax Rate (%): "))

cogs = sales * 0.4
gross_profit = sales - cogs
taxes = rate * gross_profit
net = gross_profit - taxes

print(f"Sales: {sales}$")
print(f"Cost of Goods Sold: {cogs}$")
print(f"Gross Profit: {gross_profit}$")
print(f"Taxes: {taxes}$")
print(f"Net Income: {net}$")
# Out:
# Enter Sales ($): 12000
# Enter Tax Rate (%): 0.3
# Sales: 12000.0$
# Cost of Goods Sold: 4800.0$
# Gross Profit: 7200.0$
# Taxes: 2160.0$
# Net Income: 5040.0$

# %%
num1 = float(input("Enter first number: "))
num2 = float(input("Enter second number: "))
op = input("Choose numerical operator: ")

if op == "+":
  res = num1 + num2
elif op == "-":
  res = num1 - num2
elif op == "*":
  res = num1 * num2
elif op == "/":
  res = num1 / num2
elif op == "//":
  res = num1 // num2
elif op == "**":
  res = num1 ** num2
elif op == "%":
  res = num1 % num2
else:
  print("Invalid operation" )
  res = None

print(f"Result: {res}")
# Out:
# Enter first number: 1
# Enter second number: 2
# Choose numerical operator: 4
# Invalid operation
# Result: None

# %%
for hour in range(1, 9):
  fee = 5 + 2.5 * hour
  if fee < 10:
    fee = 10.0
  elif fee > 20:
    fee = 20.0
  print(hour, fee)
# Out:
# 1 10.0
# 2 10.0
# 3 12.5
# 4 15.0
# 5 17.5
# 6 20.0
# 7 20.0
# 8 20.0

# %%
ticket = 20
init_attendees = 20
fixed_cost = 200

for ad in range (0,201,25):
  revenue = (init_attendees + 2 * round(ad ** 0.5)) * 10
  costs = fixed_cost + ad
  profit = revenue - costs
  print(ad,profit)
# Out:
# 0 0
# 25 75
# 50 90
# 75 105
# 100 100
# 125 95
# 150 90
# 175 85
# 200 80

# %%
hour = 1
while hour < 9:
  fee = 5 + 2.5 * hour
  if fee < 10:
    fee = 10.0
  elif fee > 20:
    fee = 20.0
  print(hour, fee)
  hour += 1
# Out:
# 1 10.0
# 2 10.0
# 3 12.5
# 4 15.0
# 5 17.5
# 6 20.0
# 7 20.0
# 8 20.0

# %%
import math

ticket = 20
init_attendees = 20
fixed_cost = 200

ad = 0
while ad < 201:
  revenue = (init_attendees + 2 * round(math.sqrt(ad))) * 10
  costs = fixed_cost + ad
  profit = revenue - costs
  print(ad,profit)
  ad += 25
# Out:
# 0 0
# 25 75
# 50 90
# 75 105
# 100 100
# 125 95
# 150 90
# 175 85
# 200 80

# %%
import random

play = input("Do you want to play? (y/n): ").lower()

while play == "y":
    p_move = input("Choose between rock, paper, scissors: ").lower()
    c_move = random.choice(['rock', 'paper', 'scissors'])

    print(f"Player move: {p_move}")
    print(f"Computer move: {c_move}")

    if p_move == c_move:
        print("Draw")
    elif (
        (p_move == "rock" and c_move == "scissors") or
        (p_move == "scissors" and c_move == "paper") or
        (p_move == "paper" and c_move == "rock")
    ):
        print("Player wins!")
    else:
        print("Computer wins!")

    play = input("Do you want to play again? (y/n): ").lower()
# Out:
# Do you want to play? (y/n): y
# Choose between rock, paper, scissors: rock
# Player move: rock
# Computer move: scissors
# Player wins!
# Do you want to play again? (y/n): y
# Choose between rock, paper, scissors: paper
# Player move: paper
# Computer move: paper
# Draw
# Do you want to play again? (y/n): y
# Choose between rock, paper, scissors: paper
# Player move: paper
# Computer move: rock
# Player wins!
# Do you want to play again? (y/n): n

# %%
numbers = []

while True:
    num = float(input("Give a number: "))
    if num == 0:
        break
    numbers.append(num)

numbers.sort(reverse=True)
print(numbers)
# Out:
# Give a number: 6
# Give a number: 7
# Give a number: 5
# Give a number: 8
# Give a number: 3
# Give a number: 0
# [8.0, 7.0, 6.0, 5.0, 3.0]

# %%
weights = [10.0, 9.9, 10.1, 10.05]

print(sum(weights) / len(weights))
print(max(weights))
# Out:
# 10.0125
# 10.1

# %%
products = {
    "P-01": 9.95,
    "P-02": 10.5
}

id = input("Enter product ID: ")

print(products.get(id, f"Product {id} not found..."))
# Out:
# Enter product ID: P-01
# 9.95

# %%
names = {}

while True:
    name = input("Give a name: ")
    if name == "":
        break

    if name in names:
        names[name] += 1
    else:
        names[name] = 1

print(names)
# Out:
# Give a name: Nick
# Give a name: Nick
# Give a name: 67
# Give a name:
# {'Nick': 2, '67': 1}

# %%
def calcFee(hour):
  fee = 5 + 2.5 * hour
  if fee < 10:
    fee = 10.0
  elif fee > 20:
    fee = 20.0
  print(fee)

def main():
  hour = int(input('Enter number of hours parked:'))
  calcFee(hour)

main()
# Out:
# Enter number of hours parked:5
# 17.5

# %%
def reverse(s):
  if len(s) < 2:
    return s
  else:
    #return s[-1] + reverse(s[:-1]) #take the last char and put it first
    #return reverse(s[1:]) + s[0]) #take the first char and put it last
    return s[-1] + reverse(s[1:-1]) + s[0]

  reverse('12345')

# %%
def roi(revenue, cost):
  assert cost != 0
  assert isinstance(revenue,(int,float))
  return (revenue - cost) / cost

# %%
def loan_payment(principal, annual_rate, months):
    assert isinstance(principal, (int, float))
    assert isinstance(annual_rate, (int, float))
    assert isinstance(months, int)

    if principal <= 0 or annual_rate <= 0 or months <= 0:
        raise ValueError("Invalid input values")

    try:
        r = annual_rate / 12 / 100
        if r == 0:
            pmt = principal / months
        else:
            pmt = r * principal / (1 - (1 + r) ** (-months))
    except Exception as e:
        raise Exception(f"Error: {e}")

    return pmt

# %%
class Greeting:
    def __init__(self, first, last):
        self.first = first
        self.last = last

    def display(self, formal=False):
        if formal:
            print(f"{self.last}, {self.first}")
        else:
            print(f"{self.first}")

    def __str__(self):
        return "Class Greeting \nReturns formal or informal greetings"

s = Greeting("John", "Doe")
print(s)
s.display()
s.display(formal=True)
# Out:
# Class Greeting
# Returns formal or informal greetings
# John
# Doe, John

# %%
class Student:
    def __init__(self, name, number):
        self.__name = name
        self.number = number
        self.__courses = []

    def get_courses(self):
        return self.__courses

    def get_name(self):
        return self.__name

    def set_name(self, newName):
        self.__name = newName

    def __len__(self):
        return len(self.__courses)

    def enroll(self, course):
        if course in self.__courses:
            print(f"Student {self.__name} has already enrolled in course {course}.")
        else:
            self.__courses.append(course)

# %%
s = Student("Jane Doe", 12345)
print("Student name:", s.get_name())
s.set_name("Jane B. Doe")
print("Student name:", s.get_name())
print("Courses enrolled in:", s.get_courses())
s.enroll('BTE320')
s.enroll('BTE320')
print(f"Student {s.get_name()} has enrolled in {len(s)} course(s): {s.get_courses()}")
# Out:
# Student name: Jane Doe
# Student name: Jane B. Doe
# Courses enrolled in: []
# Student Jane B. Doe has already enrolled in course BTE320.
# Student Jane B. Doe has enrolled in 1 course(s): ['BTE320']

# %%
class Point:
    def __init__(self, x, y):
        self.x = x
        self.y = y

    def distance(self, other):
        dx = (self.x - other.x) ** 2
        dy = (self.y - other.y) ** 2
        dist = (dx + dy) ** 0.5
        return dist

class Rectangle:
    def __init__(self, x1, y1, x2, y2, x3, y3, x4, y4):
        self.p1 = Point(x1, y1)  # upper left
        self.p2 = Point(x2, y2)  # upper right
        self.p3 = Point(x3, y3)  # lower left
        self.p4 = Point(x4, y4)  # lower right
        self.width = self.p1.distance(self.p2)
        self.height = self.p1.distance(self.p3)

    def area(self):
        return self.width * self.height

    def perimeter(self):
        return

# %%
square = Rectangle(0, 3, 3, 3, 0, 0, 3, 0)
square.area()
# Out:
# 9.0

# %%
class Employee:
    def __init__(self, name, hourly_wage, hours):
        self.name = name
        self._hourly_wage = hourly_wage
        self.hours = hours

    def get_wage(self):
        return self._hourly_wage

    def set_wage(self, newWage):
        self._hourly_wage = newWage

    def calculate_pay(self):
        return self._hourly_wage * self.hours

    def __str__(self):
        return f"Employee Name: {self.name}\nHourly Charge: {self._hourly_wage}$"

class Manager(Employee):
    def __init__(self, name, hourly_wage, hours, bonus):
        super().__init__(name, hourly_wage, hours)
        self.bonus = bonus  # float between 0 - 1 i.e., 0.2 means 20% extra

    def calculate_pay(self):
        return (1 + self.bonus) * super().get_wage() * self.hours

employee = Employee("John", 10, 3)
manager = Manager("Alice", 30, 15, 0.2)

print(employee)
print(manager)
print(f"Employee {employee.name} weekly salary: {employee.calculate_pay()}$")
print(f"Manager {manager.name} weekly salary: {manager.calculate_pay()}$ that includes a {manager.bonus * 100}% bonus.")
# Out:
# Employee Name: John
# Hourly Charge: 10$
# Employee Name: Alice
# Hourly Charge: 30$
# Employee John weekly salary: 30$
# Manager Alice weekly salary: 540.0$ that includes a 20.0% bonus.
